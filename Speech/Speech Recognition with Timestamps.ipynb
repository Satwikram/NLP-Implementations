# %% [markdown]
# <a href="https://colab.research.google.com/github/Satwikram/NLP-Implementations/blob/main/Speech/Speech%20Recognition%20with%20Timestamps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Speech recognition with timestamps with vosk

# %% [markdown]
# ### Setup

# %%
# !pip install vosk
# Out:
# Installing collected packages: websockets, srt, vosk
# Successfully installed srt-3.5.3 vosk-0.3.45 websockets-11.0.2

# %%
# !wget https://alphacephei.com/vosk/models/vosk-model-en-us-0.21.zip

# %%
# !unzip /content/vosk-model-en-us-0.21.zip

# %% [markdown]
# ## Import Libraries

# %%
import os
import sys
import wave
import json

from vosk import Model, KaldiRecognizer, SetLogLevel

SetLogLevel(0)

# %%
class Word:
    ''' A class representing a word from the JSON format for vosk speech recognition API '''

    def __init__(self, dict):
        '''
        Parameters:
          dict (dict) dictionary from JSON, containing:
            conf (float): degree of confidence, from 0 to 1
            end (float): end time of the pronouncing the word, in seconds
            start (float): start time of the pronouncing the word, in seconds
            word (str): recognized word
        '''

        self.conf = dict["conf"]
        self.end = dict["end"]
        self.start = dict["start"]
        self.word = dict["word"]

    def to_string(self):
        ''' Returns a string describing this instance '''
        return "{:20} from {:.2f} sec to {:.2f} sec, confidence is {:.2f}%".format(
            self.word, self.start, self.end, self.conf*100)

# %% [markdown]
# ## Loading a vosk model

# %%
# path to vosk model downloaded from
# https://alphacephei.com/vosk/models
model_path = "/content/vosk-model-en-us-0.21"

if not os.path.exists(model_path):
    print(f"Please download the model from https://alphacephei.com/vosk/models and unpack as {model_path}")
    sys.exit()

print(f"Reading your vosk model '{model_path}'...")
model = Model(model_path)
print(f"'{model_path}' model was successfully read")
# Out:
# Reading your vosk model '/content/vosk-model-en-us-0.21'...
# '/content/vosk-model-en-us-0.21' model was successfully read

# %% [markdown]
# ## Specify the file name to recognize

# %%
# name of the audio file to recognize
audio_filename = "/content/drive/MyDrive/Participant 2.wav"
# name of the text file to write recognized text
text_filename = "output.txt"

# %% [markdown]
# ## Reading a file

# %%
if not os.path.exists(audio_filename):
    print(f"File '{audio_filename}' doesn't exist")
    sys.exit()

print(f"Reading your file '{audio_filename}'...")
wf = wave.open(audio_filename, "rb")
print(f"'{audio_filename}' file was successfully read")
# Out:
# Reading your file '/content/drive/MyDrive/Participant 2.wav'...
# '/content/drive/MyDrive/Participant 2.wav' file was successfully read

# %%
# check if audio is mono wav
if wf.getnchannels() != 1 or wf.getsampwidth() != 2 or wf.getcomptype() != "NONE":
    print("Audio file must be WAV format mono PCM.")
    sys.exit()

# %% [markdown]
# ## Recognize

# %%
rec = KaldiRecognizer(model, wf.getframerate())
rec.SetWords(True)

# %%
results = []

# recognize speech using vosk model
while True:
    data = wf.readframes(4000)
    if len(data) == 0:
        break
    if rec.AcceptWaveform(data):
        part_result = json.loads(rec.Result())
        results.append(part_result)

part_result = json.loads(rec.FinalResult())
results.append(part_result)

# %%
results
# Out:
# [{'result': [{'conf': 0.554866, 'end': 0.63, 'start': 0.0, 'word': 'there'}],
#   'text': 'there'},
#  {'text': ''},
#  {'result': [{'conf': 0.93374, 'end': 9.18, 'start': 8.97, 'word': 'i'},
#    {'conf': 0.602859, 'end': 10.14, 'start': 9.75, 'word': 'had'},
#    {'conf': 1.0, 'end': 10.35, 'start': 10.17, 'word': 'a'},
#    {'conf': 0.5783, 'end': 10.95, 'start': 10.38, 'word': 'show'}],
#   'text': 'i had a show'},
#  {'result': [{'conf': 0.818735, 'end': 13.2, 'start': 12.9, 'word': 'my'},
#    {'conf': 0.657671, 'end': 13.53, 'start': 13.23, 'word': 'fair'},
#    {'conf': 0.657671, 'end': 13.95, 'start': 13.53, 'word': 'share'}],
#   'text': 'my fair share'},
#  {'result': [{'conf': 0.912685, 'end': 17.878222, 'start': 17.79, 'word': 'i'},
#    {'conf': 0.935475, 'end': 18.207012, 'start': 17.878222, 'word': 'have'},
#    {'conf': 1.0, 'end': 18.66, 'start': 18.24, 'word': 'hush'},
#    {'conf': 1.0, 'end': 19.23, 'start': 18.72, 'word': 'hush'},
#    {'conf': 1.0, 'end': 19.74, 'start': 19.26, 'word': 'hush'},
#    {'conf': 0.685414, 'end': 20.46, 'start': 19.74, 'word': 'child'}],
#   'text': 'i have hush hush hush child'},
#  {'result': [{'conf': 1.0, 'end': 22.351298, 'start': 21.6, 'word': 'the'},
#    {'conf': 0.458957, 'end': 23.1, 'start': 22.59, 'word': 'act'},
#    {'conf': 0.454306, 'end': 23.46, 'start': 23.37, 'word': 'of'},
#    {'conf': 0.454306, 'end': 24.15, 'start': 23.79, 'word': 'murder'}],
#   'text': 'the act of murder'},
#  {'result': [{'conf': 0.529818,
#     'end': 28.83,
#     'start': 27.33,
#     'word': 'around'},
#    {'conf': 0.733049, 'end': 29.13, 'start': 28.83, 'word': 'this'},
#    {'conf': 0.719591, 'end': 29.76, 'start': 29.16, 'word': 'time'}],
#   'text': 'around this time'},
#  {'result': [{'conf': 0.716724, 'end': 31.59, 'start': 31.11, 'word': 'share'},
#    {'conf': 0.337525, 'end': 32.67, 'start': 32.19, 'word': 'this'},
#    {'conf': 0.24542, 'end': 33.63, 'start': 32.712528, 'word': 'tours'}],
#   'text': 'share this tours'},
#  {'result': [{'conf': 0.793338, 'end': 35.76, 'start': 35.49, 'word': 'when'},
#    {'conf': 0.793338, 'end': 36.06, 'start': 35.76, 'word': 'asked'},
#    {'conf': 1.0, 'end': 36.84, 'start': 36.42, 'word': 'about'},
#    {'conf': 1.0, 'end': 37.65, 'start': 36.9, 'word': 'a'},
#    {'conf': 0.735224, 'end': 38.34, 'start': 37.68, 'word': 'show'},
#    {'conf': 0.746995, 'end': 38.88, 'start': 38.37, 'word': 'so'}],
#   'text': 'when asked about a show so'},
#  {'result': [{'conf': 0.89735, 'end': 40.8, 'start': 40.41, 'word': 'that'},
#    {'conf': 0.406623, 'end': 41.422357, 'start': 40.83, 'word': 'shrimp'},
#    {'conf': 1.0, 'end': 42.21, 'start': 41.422357, 'word': 'said'},
#    {'conf': 0.881383, 'end': 43.17, 'start': 42.99, 'word': 'the'},
#    {'conf': 0.621646, 'end': 44.55, 'start': 43.59, 'word': 'cash'},
#    {'conf': 0.616507, 'end': 44.91, 'start': 44.58, 'word': 'gave'},
#    {'conf': 0.616507, 'end': 45.21, 'start': 44.91, 'word': 'me'}],
#   'text': 'that shrimp said the cash gave me'},
#  {'text': ''},
#  {'result': [{'conf': 1.0, 'end': 51.54, 'start': 51.06, 'word': 'you'},
#    {'conf': 1.0, 'end': 54.3, 'start': 53.91, 'word': 'can'},
#    {'conf': 0.647828, 'end': 55.29, 'start': 54.3, 'word': 'have'},
#    {'conf': 0.608264, 'end': 55.536233, 'start': 55.32, 'word': 'a'},
#    {'conf': 0.445047, 'end': 57.36, 'start': 56.61, 'word': 'attack'}],
#   'text': 'you can have a attack'},
#  {'result': [{'conf': 1.0, 'end': 58.74, 'start': 58.32, 'word': 'from'},
#    {'conf': 1.0, 'end': 59.798544, 'start': 59.37, 'word': 'our'},
#    {'conf': 0.667789, 'end': 60.12, 'start': 59.798544, 'word': 'enough'},
#    {'conf': 0.66553, 'end': 60.93, 'start': 60.45, 'word': 'shelter'}],
#   'text': 'from our enough shelter'},
#  {'result': [{'conf': 1.0, 'end': 62.7, 'start': 62.52, 'word': 'he'},
#    {'conf': 1.0, 'end': 62.79, 'start': 62.7, 'word': 'or'},
#    {'conf': 1.0, 'end': 63.12, 'start': 62.79, 'word': 'she'},
#    {'conf': 1.0, 'end': 63.42, 'start': 63.12, 'word': 'will'},
#    {'conf': 1.0, 'end': 64.74, 'start': 63.45, 'word': 'cherish'},
#    {'conf': 0.780163, 'end': 65.52, 'start': 64.8, 'word': 'ash'}],
#   'text': 'he or she will cherish ash'},
#  {'result': [{'conf': 0.666766,
#     'end': 69.18,
#     'start': 68.25,
#     'word': 'sugar'}],
#   'text': 'sugar'},
#  {'result': [{'conf': 1.0, 'end': 73.38, 'start': 72.75, 'word': 'key'},
#    {'conf': 1.0, 'end': 74.04, 'start': 73.47, 'word': 'key'}],
#   'text': 'key key'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.634016, 'end': 104.61, 'start': 104.01, 'word': 'you'},
#    {'conf': 0.628864, 'end': 105.09, 'start': 104.612761, 'word': 'can'}],
#   'text': 'you can'},
#  {'result': [{'conf': 0.557652, 'end': 108.96, 'start': 108.18, 'word': 'a'}],
#   'text': 'a'},
#  {'result': [{'conf': 0.420824,
#     'end': 112.02,
#     'start': 111.60572,
#     'word': 'this'},
#    {'conf': 0.483929, 'end': 112.89, 'start': 112.02, 'word': 'time'}],
#   'text': 'this time'},
#  {'result': [{'conf': 0.624134,
#     'end': 114.69,
#     'start': 114.0,
#     'word': 'roche'},
#    {'conf': 0.627453, 'end': 114.97804, 'start': 114.72, 'word': 'and'},
#    {'conf': 0.837731, 'end': 115.32, 'start': 114.97804, 'word': 'an'},
#    {'conf': 0.958081, 'end': 115.86, 'start': 115.38, 'word': 'outer'},
#    {'conf': 0.958081, 'end': 116.485078, 'start': 115.86, 'word': 'shell'}],
#   'text': 'roche and an outer shell'},
#  {'result': [{'conf': 0.620828,
#     'end': 120.479238,
#     'start': 119.94,
#     'word': 'shirt'},
#    {'conf': 0.516462, 'end': 120.81, 'start': 120.48, 'word': 'can'}],
#   'text': 'shirt can'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.520214, 'end': 142.77, 'start': 142.5, 'word': 'hey'},
#    {'conf': 0.732272, 'end': 144.93, 'start': 144.51, 'word': 'hey'},
#    {'conf': 0.420407, 'end': 145.35, 'start': 145.05, 'word': 'hey'}],
#   'text': 'hey hey hey'},
#  {'text': ''},
#  {'result': [{'conf': 0.341024, 'end': 154.08, 'start': 153.06, 'word': 'g'}],
#   'text': 'g'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.324642, 'end': 177.57, 'start': 177.12, 'word': 'it'},
#    {'conf': 0.445236, 'end': 179.64, 'start': 179.16, 'word': 'asked'}],
#   'text': 'it asked'},
#  {'result': [{'conf': 0.367027, 'end': 182.52, 'start': 182.31, 'word': 'up'}],
#   'text': 'up'},
#  {'text': ''},
#  {'result': [{'conf': 0.384737,
#     'end': 189.39,
#     'start': 188.88,
#     'word': 'the'}],
#   'text': 'the'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.447927, 'end': 208.2, 'start': 205.68, 'word': 'hi'}],
#   'text': 'hi'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.824469, 'end': 225.15, 'start': 224.76, 'word': 'it'},
#    {'conf': 0.543003, 'end': 225.57, 'start': 225.18, 'word': 'should'}],
#   'text': 'it should'},
#  {'result': [{'conf': 1.0, 'end': 227.886299, 'start': 227.19, 'word': 'a'},
#    {'conf': 0.204264, 'end': 228.45, 'start': 227.886299, 'word': 'p'}],
#   'text': 'a p'},
#  {'result': [{'conf': 0.324083, 'end': 230.16, 'start': 229.95, 'word': 'in'},
#    {'conf': 0.43369, 'end': 231.9, 'start': 230.25, 'word': 'aviation'}],
#   'text': 'in aviation'},
#  {'result': [{'conf': 0.852215, 'end': 234.36, 'start': 233.46, 'word': 'a'},
#    {'conf': 0.634702, 'end': 234.900381, 'start': 234.42, 'word': 'term'},
#    {'conf': 0.421909, 'end': 235.38, 'start': 234.93, 'word': 'tracker'}],
#   'text': 'a term tracker'},
#  {'result': [{'conf': 0.235538,
#     'end': 240.35644,
#     'start': 239.651104,
#     'word': 'teaching'}],
#   'text': 'teaching'},
#  {'result': [{'conf': 0.83564, 'end': 244.05, 'start': 243.69, 'word': 'how'},
#    {'conf': 0.83564, 'end': 244.62, 'start': 244.08, 'word': 'can'},
#    {'conf': 1.0, 'end': 245.52, 'start': 245.37, 'word': 'the'},
#    {'conf': 1.0, 'end': 246.0, 'start': 245.52, 'word': 'right'},
#    {'conf': 1.0, 'end': 246.09, 'start': 246.0, 'word': 'or'},
#    {'conf': 1.0, 'end': 246.24, 'start': 246.09, 'word': 'the'},
#    {'conf': 1.0, 'end': 246.93, 'start': 246.54, 'word': 'left'}],
#   'text': 'how can the right or the left'},
#  {'result': [{'conf': 1.0,
#     'end': 252.84,
#     'start': 252.281104,
#     'word': 'sure'}],
#   'text': 'sure'},
#  {'result': [{'conf': 0.612305,
#     'end': 257.13,
#     'start': 256.268555,
#     'word': 'sugar'}],
#   'text': 'sugar'},
#  {'result': [{'conf': 1.0, 'end': 262.292139, 'start': 261.66, 'word': 'a'},
#    {'conf': 0.618476, 'end': 263.28, 'start': 262.32, 'word': 'chain'}],
#   'text': 'a chain'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.641716, 'end': 308.55, 'start': 308.19, 'word': 'she'},
#    {'conf': 0.425576, 'end': 309.48, 'start': 308.552813, 'word': 'dead'}],
#   'text': 'she dead'},
#  {'result': [{'conf': 0.821984, 'end': 313.26, 'start': 312.69, 'word': 'do'},
#    {'conf': 0.38097, 'end': 313.98, 'start': 313.29, 'word': 'say'},
#    {'conf': 1.0, 'end': 314.97, 'start': 314.018848, 'word': 'change'}],
#   'text': 'do say change'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.235365, 'end': 345.99, 'start': 345.6, 'word': 'he'}],
#   'text': 'he'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.484769,
#     'end': 381.96,
#     'start': 381.72,
#     'word': 'she'}],
#   'text': 'she'},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.450545, 'end': 395.1, 'start': 394.68, 'word': 'why'}],
#   'text': 'why'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 1.0, 'end': 415.655537, 'start': 415.23, 'word': 'yeah'},
#    {'conf': 0.413694, 'end': 416.34, 'start': 415.692715, 'word': 'a'},
#    {'conf': 0.332308, 'end': 416.720332, 'start': 416.37, 'word': 'can'}],
#   'text': 'yeah a can'},
#  {'result': [{'conf': 0.940571,
#     'end': 422.42165,
#     'start': 422.07,
#     'word': 'she'},
#    {'conf': 0.465404, 'end': 422.7, 'start': 422.43, 'word': 'made'},
#    {'conf': 0.655631, 'end': 423.27, 'start': 422.73, 'word': 'machine'}],
#   'text': 'she made machine'},
#  {'result': [{'conf': 0.645621,
#     'end': 426.75,
#     'start': 425.752178,
#     'word': 'me'},
#    {'conf': 0.538287, 'end': 428.07, 'start': 427.41, 'word': 'a'}],
#   'text': 'me a'},
#  {'result': [{'conf': 0.432117, 'end': 434.31, 'start': 434.01, 'word': 'did'},
#    {'conf': 0.91364, 'end': 435.087012, 'start': 434.484756, 'word': 'the'},
#    {'conf': 0.903301, 'end': 436.146592, 'start': 435.521162, 'word': 'same'},
#    {'conf': 0.890827, 'end': 436.83, 'start': 436.407715, 'word': 'thing'}],
#   'text': 'did the same thing'},
#  {'text': ''},
#  {'result': [{'conf': 0.756775, 'end': 445.44, 'start': 444.24, 'word': 'you'},
#    {'conf': 0.723648, 'end': 446.85, 'start': 446.49, 'word': 'know'},
#    {'conf': 0.703337, 'end': 447.09, 'start': 446.91, 'word': 'the'},
#    {'conf': 0.801005, 'end': 447.714785, 'start': 447.091729, 'word': 'new'},
#    {'conf': 0.296846, 'end': 448.14, 'start': 447.72, 'word': 'team'}],
#   'text': 'you know the new team'},
#  {'result': [{'conf': 0.595841,
#     'end': 452.054648,
#     'start': 451.29,
#     'word': 'ah'},
#    {'conf': 0.680529, 'end': 452.88, 'start': 452.207402, 'word': 'search'},
#    {'conf': 0.781334, 'end': 454.14, 'start': 453.6, 'word': 'for'},
#    {'conf': 0.536228, 'end': 455.67, 'start': 454.14, 'word': 'catfish'}],
#   'text': 'ah search for catfish'},
#  {'result': [{'conf': 1.0, 'end': 456.951475, 'start': 456.57, 'word': 'a'},
#    {'conf': 0.545564, 'end': 457.59, 'start': 456.96, 'word': 'gish'}],
#   'text': 'a gish'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.759103, 'end': 518.4, 'start': 517.86, 'word': 'i'},
#    {'conf': 0.58823, 'end': 519.0, 'start': 518.43, 'word': 'come'}],
#   'text': 'i come'},
#  {'result': [{'conf': 0.399932,
#     'end': 524.64,
#     'start': 524.19,
#     'word': 'have'},
#    {'conf': 0.682273, 'end': 525.236895, 'start': 524.79, 'word': 'lost'},
#    {'conf': 0.925764, 'end': 525.93, 'start': 525.236895, 'word': 'touch'}],
#   'text': 'have lost touch'},
#  {'result': [{'conf': 0.601181, 'end': 529.23, 'start': 528.63, 'word': 'ah'},
#    {'conf': 0.912909, 'end': 530.37, 'start': 529.240605, 'word': 'sasha'},
#    {'conf': 0.519196, 'end': 530.58, 'start': 530.46, 'word': 'or'},
#    {'conf': 0.8839, 'end': 531.350977, 'start': 530.58, 'word': 'fast'},
#    {'conf': 0.521105, 'end': 532.5, 'start': 531.350977, 'word': 'tours'}],
#   'text': 'ah sasha or fast tours'},
#  {'result': [{'conf': 0.743269,
#     'end': 534.567363,
#     'start': 533.804824,
#     'word': 'have'},
#    {'conf': 0.612282, 'end': 534.99, 'start': 534.567363, 'word': 'four'}],
#   'text': 'have four'},
#  {'result': [{'conf': 0.403083,
#     'end': 538.44,
#     'start': 537.694687,
#     'word': 'capcom'}],
#   'text': 'capcom'},
#  {'result': [{'conf': 0.766771,
#     'end': 540.264141,
#     'start': 539.58,
#     'word': 'first'},
#    {'conf': 0.460547, 'end': 540.39, 'start': 540.27, 'word': 'i'},
#    {'conf': 0.260219, 'end': 540.779063, 'start': 540.42, 'word': 'had'},
#    {'conf': 0.212718, 'end': 541.41, 'start': 540.78, 'word': 'bow'}],
#   'text': 'first i had bow'},
#  {'result': [{'conf': 0.933142,
#     'end': 542.28,
#     'start': 541.56,
#     'word': 'shared'},
#    {'conf': 0.933142, 'end': 543.9, 'start': 543.12, 'word': 'stash'}],
#   'text': 'shared stash'},
#  {'result': [{'conf': 0.350986,
#     'end': 549.12,
#     'start': 548.55,
#     'word': "she's"},
#    {'conf': 0.708754, 'end': 549.48, 'start': 549.21, 'word': 'a'}],
#   'text': "she's a"},
#  {'result': [{'conf': 0.767614,
#     'end': 553.02,
#     'start': 551.82,
#     'word': 'softly'},
#    {'conf': 0.967428, 'end': 553.92, 'start': 553.47, 'word': 'at'},
#    {'conf': 0.974167, 'end': 554.192344, 'start': 553.92, 'word': 'that'},
#    {'conf': 0.296038, 'end': 554.85, 'start': 554.192344, 'word': 'sir'}],
#   'text': 'softly at that sir'},
#  {'result': [{'conf': 0.497902,
#     'end': 556.017246,
#     'start': 555.6,
#     'word': 'that'},
#    {'conf': 0.270517, 'end': 556.452832, 'start': 556.017246, 'word': 'shot'}],
#   'text': 'that shot'},
#  {'result': [{'conf': 0.388857,
#     'end': 559.17,
#     'start': 558.761777,
#     'word': 'here'},
#    {'conf': 0.720909, 'end': 559.38, 'start': 559.178965, 'word': 'to'},
#    {'conf': 0.946572, 'end': 559.98, 'start': 559.388789, 'word': 'teach'},
#    {'conf': 0.729354, 'end': 560.299277, 'start': 560.01, 'word': 'me'},
#    {'conf': 0.76246, 'end': 560.518418, 'start': 560.342637, 'word': 'to'},
#    {'conf': 0.729245, 'end': 561.012246, 'start': 560.81127, 'word': 'a'},
#    {'conf': 0.601723, 'end': 561.54, 'start': 561.15, 'word': 'key'}],
#   'text': 'here to teach me to a key'},
#  {'result': [{'conf': 0.610049, 'end': 564.51, 'start': 564.33, 'word': 'you'},
#    {'conf': 0.331104, 'end': 564.854062, 'start': 564.51, 'word': 'should'},
#    {'conf': 0.807983, 'end': 565.47, 'start': 564.854062, 'word': 'there'}],
#   'text': 'you should there'},
#  {'result': [{'conf': 0.988437,
#     'end': 567.87,
#     'start': 566.64,
#     'word': 'hush'},
#    {'conf': 0.485529, 'end': 569.152617, 'start': 568.59, 'word': 'song'},
#    {'conf': 0.929034, 'end': 569.46, 'start': 569.152617, 'word': 'she'},
#    {'conf': 0.89903, 'end': 569.94, 'start': 569.46, 'word': 'saw'},
#    {'conf': 0.587671, 'end': 570.87, 'start': 570.24, 'word': 'you'}],
#   'text': 'hush song she saw you'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.234634,
#     'end': 616.553313,
#     'start': 615.653313,
#     'word': 'shoe'}],
#   'text': 'shoe'},
#  {'text': ''},
#  {'result': [{'conf': 0.250852,
#     'end': 627.443313,
#     'start': 626.693313,
#     'word': 'horrible'},
#    {'conf': 0.758474, 'end': 628.733313, 'start': 627.864816, 'word': 'show'}],
#   'text': 'horrible show'},
#  {'result': [{'conf': 0.996059,
#     'end': 630.938044,
#     'start': 630.171784,
#     'word': 'i'},
#    {'conf': 0.928604, 'end': 631.563082, 'start': 630.965971, 'word': 'can'},
#    {'conf': 0.310669, 'end': 633.173313, 'start': 632.303313, 'word': 'chat'}],
#   'text': 'i can chat'},
#  {'result': [{'conf': 0.904327,
#     'end': 633.981714,
#     'start': 633.383313,
#     'word': 'still'},
#    {'conf': 0.238527, 'end': 634.283313, 'start': 633.983313, 'word': 'have'},
#    {'conf': 0.989909, 'end': 634.913313, 'start': 634.703313, 'word': 'to'},
#    {'conf': 0.940043, 'end': 635.723313, 'start': 634.913313, 'word': 'show'},
#    {'conf': 1.0, 'end': 636.653313, 'start': 635.783313, 'word': 'child'}],
#   'text': 'still have to show child'},
#  {'text': ''},
#  {'result': [{'conf': 0.532065,
#     'end': 645.443313,
#     'start': 645.293313,
#     'word': 'he'},
#    {'conf': 0.89262, 'end': 645.683313, 'start': 645.443313, 'word': 'may'},
#    {'conf': 0.89262, 'end': 646.223313, 'start': 645.713313, 'word': 'be'},
#    {'conf': 1.0, 'end': 647.093313, 'start': 646.223313, 'word': 'she'}],
#   'text': 'he may be she'},
#  {'result': [{'conf': 0.229556,
#     'end': 651.923313,
#     'start': 650.873313,
#     'word': 'crash'}],
#   'text': 'crash'},
#  {'result': [{'conf': 0.396669,
#     'end': 653.333313,
#     'start': 653.033313,
#     'word': 'lol'},
#    {'conf': 0.457759, 'end': 654.473313, 'start': 653.963313, 'word': 'yes'}],
#   'text': 'lol yes'},
#  {'result': [{'conf': 0.766464,
#     'end': 657.503313,
#     'start': 657.233313,
#     'word': 'she'},
#    {'conf': 0.35961, 'end': 657.738907, 'start': 657.503313, 'word': 'will'}],
#   'text': 'she will'},
#  {'result': [{'conf': 0.854335,
#     'end': 661.373313,
#     'start': 660.563313,
#     'word': 'cash'}],
#   'text': 'cash'},
#  {'result': [{'conf': 0.451512,
#     'end': 663.053313,
#     'start': 662.723313,
#     'word': 'the'},
#    {'conf': 0.883035,
#     'end': 664.073313,
#     'start': 663.083313,
#     'word': 'catfish'},
#    {'conf': 0.964749, 'end': 664.613313, 'start': 664.103313, 'word': 'can'},
#    {'conf': 0.964749, 'end': 665.453313, 'start': 664.643313, 'word': 'chew'},
#    {'conf': 1.0, 'end': 666.293313, 'start': 665.483313, 'word': 'january'},
#    {'conf': 0.950884, 'end': 667.253313, 'start': 666.713313, 'word': 'ball'}],
#   'text': 'the catfish can chew january ball'},
#  {'result': [{'conf': 0.928408,
#     'end': 670.733313,
#     'start': 669.803313,
#     'word': 'caching'},
#    {'conf': 0.398662, 'end': 671.204568, 'start': 670.793313, 'word': 'from'},
#    {'conf': 0.514189, 'end': 672.713313, 'start': 672.023313, 'word': 'true'}],
#   'text': 'caching from true'},
#  {'result': [{'conf': 1.0,
#     'end': 675.503313,
#     'start': 675.293313,
#     'word': 'oh'},
#    {'conf': 1.0, 'end': 677.273313, 'start': 676.703313, 'word': 'shucks'},
#    {'conf': 0.932923, 'end': 677.453313, 'start': 677.273313, 'word': 'to'},
#    {'conf': 0.932923, 'end': 677.903313, 'start': 677.453313, 'word': 'try'}],
#   'text': 'oh shucks to try'},
#  {'result': [{'conf': 0.512107,
#     'end': 680.479775,
#     'start': 680.039568,
#     'word': 'ha'},
#    {'conf': 0.991098, 'end': 681.203313, 'start': 680.933313, 'word': 'and'},
#    {'conf': 1.0, 'end': 681.833313, 'start': 681.233049, 'word': 'try'},
#    {'conf': 1.0, 'end': 682.583313, 'start': 682.373313, 'word': 'to'},
#    {'conf': 0.47353, 'end': 683.393313, 'start': 683.003313, 'word': 'block'},
#    {'conf': 0.761159, 'end': 683.543313, 'start': 683.393313, 'word': 'the'},
#    {'conf': 0.761159, 'end': 684.009536, 'start': 683.543313, 'word': 'path'},
#    {'conf': 0.905718, 'end': 684.353313, 'start': 684.009536, 'word': 'from'}],
#   'text': 'ha and try to block the path from'},
#  {'text': ''},
#  {'result': [{'conf': 0.640666,
#     'end': 691.913313,
#     'start': 690.983313,
#     'word': 'sugar'}],
#   'text': 'sugar'},
#  {'result': [{'conf': 0.764415,
#     'end': 695.873313,
#     'start': 694.973313,
#     'word': 'she'}],
#   'text': 'she'},
#  {'result': [{'conf': 0.937657,
#     'end': 697.223313,
#     'start': 696.953313,
#     'word': 'when'},
#    {'conf': 1.0, 'end': 699.053313, 'start': 697.643313, 'word': 'searching'}],
#   'text': 'when searching'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 1.0,
#     'end': 732.413313,
#     'start': 730.313313,
#     'word': 'no'}],
#   'text': 'no'},
#  {'result': [{'conf': 0.453973,
#     'end': 734.513313,
#     'start': 733.733313,
#     'word': 'szasz'},
#    {'conf': 0.498026, 'end': 734.903313, 'start': 734.663313, 'word': 'or'},
#    {'conf': 0.974953,
#     'end': 735.773313,
#     'start': 734.957922,
#     'word': 'shower'},
#    {'conf': 0.974953,
#     'end': 736.373313,
#     'start': 735.773313,
#     'word': 'shower'},
#    {'conf': 0.974953,
#     'end': 737.123313,
#     'start': 736.373313,
#     'word': 'shower'}],
#   'text': 'szasz or shower shower shower'},
#  {'result': [{'conf': 0.972446,
#     'end': 739.463313,
#     'start': 738.653313,
#     'word': 'haha'}],
#   'text': 'haha'},
#  {'result': [{'conf': 0.576262,
#     'end': 741.623313,
#     'start': 740.873313,
#     'word': 'child'}],
#   'text': 'child'},
#  {'result': [{'conf': 0.386175,
#     'end': 745.643313,
#     'start': 745.343313,
#     'word': 'they'},
#    {'conf': 0.889386, 'end': 746.003313, 'start': 745.666663, 'word': 'need'},
#    {'conf': 0.965802, 'end': 746.18324, 'start': 746.031951, 'word': 'to'},
#    {'conf': 0.955667, 'end': 746.723313, 'start': 746.18324, 'word': 'shoot'},
#    {'conf': 0.303815,
#     'end': 747.743313,
#     'start': 746.753313,
#     'word': 'babies'}],
#   'text': 'they need to shoot babies'},
#  {'result': [{'conf': 1.0,
#     'end': 750.293313,
#     'start': 749.603313,
#     'word': 'however'}],
#   'text': 'however'},
#  {'result': [{'conf': 0.382689,
#     'end': 752.153313,
#     'start': 751.733313,
#     'word': 'share'},
#    {'conf': 0.783554,
#     'end': 755.273313,
#     'start': 754.253313,
#     'word': 'share'}],
#   'text': 'share share'},
#  {'result': [{'conf': 0.648792,
#     'end': 758.653806,
#     'start': 758.213313,
#     'word': 'hey'},
#    {'conf': 0.317413, 'end': 759.023313, 'start': 758.653806, 'word': 'then'},
#    {'conf': 0.975883, 'end': 759.833313, 'start': 759.053313, 'word': 'she'},
#    {'conf': 0.769376,
#     'end': 761.093313,
#     'start': 760.253313,
#     'word': 'slowly'}],
#   'text': 'hey then she slowly'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.456889,
#     'end': 778.103313,
#     'start': 777.353313,
#     'word': 'd'}],
#   'text': 'd'},
#  {'result': [{'conf': 0.519275,
#     'end': 786.323313,
#     'start': 785.753313,
#     'word': 'ah'}],
#   'text': 'ah'},
#  {'result': [{'conf': 0.735352,
#     'end': 788.243313,
#     'start': 787.493313,
#     'word': 'last'}],
#   'text': 'last'},
#  {'result': [{'conf': 1.0,
#     'end': 792.173313,
#     'start': 791.693313,
#     'word': 'a'},
#    {'conf': 0.929842, 'end': 792.743313, 'start': 792.203313, 'word': 'cat'},
#    {'conf': 0.935863, 'end': 792.983313, 'start': 792.743313, 'word': 'at'},
#    {'conf': 0.493431, 'end': 793.403313, 'start': 792.983313, 'word': 'first'},
#    {'conf': 0.626248, 'end': 793.763313, 'start': 793.403313, 'word': 'said'},
#    {'conf': 0.864176, 'end': 794.663313, 'start': 793.793313, 'word': 'cash'}],
#   'text': 'a cat at first said cash'},
#  {'result': [{'conf': 0.332127,
#     'end': 800.393313,
#     'start': 799.133313,
#     'word': 'danish'}],
#   'text': 'danish'},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.715089,
#     'end': 814.493313,
#     'start': 813.773313,
#     'word': 'cash'}],
#   'text': 'cash'},
#  {'text': ''},
#  {'result': [{'conf': 0.763793,
#     'end': 824.423313,
#     'start': 824.033313,
#     'word': 'yeah'}],
#   'text': 'yeah'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 1.0,
#     'end': 845.843313,
#     'start': 845.363313,
#     'word': 'hush'},
#    {'conf': 1.0, 'end': 846.563313, 'start': 845.963313, 'word': 'hush'}],
#   'text': 'hush hush'},
#  {'result': [{'conf': 0.58866,
#     'end': 848.393313,
#     'start': 847.853313,
#     'word': 'ash'},
#    {'conf': 0.509456, 'end': 852.293313, 'start': 851.603313, 'word': 'park'}],
#   'text': 'ash park'},
#  {'text': ''},
#  {'result': [{'conf': 1.0,
#     'end': 858.533313,
#     'start': 857.753313,
#     'word': 'chapter'},
#    {'conf': 0.569735, 'end': 858.863313, 'start': 858.533313, 'word': 'nine'},
#    {'conf': 0.407975, 'end': 859.463313, 'start': 858.923313, 'word': 'much'},
#    {'conf': 0.978922, 'end': 860.123313, 'start': 859.853313, 'word': 'on'}],
#   'text': 'chapter nine much on'},
#  {'text': ''},
#  {'result': [{'conf': 0.186202,
#     'end': 869.873313,
#     'start': 869.363313,
#     'word': 'faster'}],
#   'text': 'faster'},
#  {'result': [{'conf': 1.0,
#     'end': 876.113313,
#     'start': 875.753313,
#     'word': 'should'},
#    {'conf': 0.920933,
#     'end': 876.653313,
#     'start': 876.113313,
#     'word': 'there'}],
#   'text': 'should there'},
#  {'result': [{'conf': 0.174052,
#     'end': 880.373313,
#     'start': 879.923313,
#     'word': 'for'},
#    {'conf': 0.538408, 'end': 880.733313, 'start': 880.433313, 'word': 'me'}],
#   'text': 'for me'},
#  {'result': [{'conf': 0.924968,
#     'end': 883.733313,
#     'start': 882.863313,
#     'word': 'yes'}],
#   'text': 'yes'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.19782,
#     'end': 919.073313,
#     'start': 918.593313,
#     'word': 'shit'}],
#   'text': 'shit'},
#  {'result': [{'conf': 0.274889,
#     'end': 922.013313,
#     'start': 921.593313,
#     'word': 'shit'}],
#   'text': 'shit'},
#  {'text': ''},
#  {'result': [{'conf': 0.571035,
#     'end': 932.573313,
#     'start': 931.853313,
#     'word': 'she'},
#    {'conf': 0.772969,
#     'end': 933.113313,
#     'start': 932.633313,
#     'word': "doesn't"},
#    {'conf': 0.944545, 'end': 933.683313, 'start': 933.263313, 'word': 'wish'},
#    {'conf': 1.0, 'end': 934.150188, 'start': 933.698284, 'word': 'to'},
#    {'conf': 1.0, 'end': 934.493313, 'start': 934.163313, 'word': 'be'},
#    {'conf': 0.423778, 'end': 935.543313, 'start': 935.033313, 'word': 'sure'}],
#   'text': "she doesn't wish to be sure"},
#  {'result': [{'conf': 0.639203,
#     'end': 940.853313,
#     'start': 939.863313,
#     'word': 'matthew'},
#    {'conf': 0.400855,
#     'end': 941.513313,
#     'start': 940.853313,
#     'word': 'parish'}],
#   'text': 'matthew parish'},
#  {'result': [{'conf': 0.570291,
#     'end': 942.093567,
#     'start': 941.884446,
#     'word': 'you'},
#    {'conf': 0.795047, 'end': 943.463313, 'start': 942.623313, 'word': 'can'}],
#   'text': 'you can'},
#  {'result': [{'conf': 0.50029,
#     'end': 946.223313,
#     'start': 945.953313,
#     'word': 'can'}],
#   'text': 'can'},
#  {'result': [{'conf': 1.0,
#     'end': 950.273313,
#     'start': 949.673313,
#     'word': 'sure'}],
#   'text': 'sure'},
#  {'result': [{'conf': 0.905285,
#     'end': 954.983313,
#     'start': 954.893313,
#     'word': 'a'},
#    {'conf': 0.905285,
#     'end': 956.693313,
#     'start': 954.983313,
#     'word': 'shocker'}],
#   'text': 'a shocker'},
#  {'text': ''},
#  {'result': [{'conf': 0.164091,
#     'end': 963.743313,
#     'start': 963.383313,
#     'word': 'j'}],
#   'text': 'j'},
#  {'text': ''},
#  {'result': [{'conf': 0.700866,
#     'end': 974.525325,
#     'start': 974.033313,
#     'word': 'there'}],
#   'text': 'there'},
#  {'result': [{'conf': 0.334054,
#     'end': 976.853313,
#     'start': 975.593313,
#     'word': 'hi'}],
#   'text': 'hi'},
#  {'text': ''},
#  {'result': [{'conf': 0.462891,
#     'end': 990.473313,
#     'start': 990.173313,
#     'word': 'yeah'}],
#   'text': 'yeah'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.382601,
#     'end': 1059.803313,
#     'start': 1058.963313,
#     'word': 'sure'}],
#   'text': 'sure'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.439939,
#     'end': 1088.183313,
#     'start': 1087.643313,
#     'word': 'game'}],
#   'text': 'game'},
#  {'result': [{'conf': 1.0,
#     'end': 1091.603313,
#     'start': 1091.063313,
#     'word': 'check'}],
#   'text': 'check'},
#  {'result': [{'conf': 0.373552,
#     'end': 1094.303313,
#     'start': 1092.713313,
#     'word': 'hey'}],
#   'text': 'hey'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 1.0,
#     'end': 1122.533313,
#     'start': 1121.753313,
#     'word': 'check'},
#    {'conf': 0.886889,
#     'end': 1122.953313,
#     'start': 1122.533313,
#     'word': 'ahead'},
#    {'conf': 1.0, 'end': 1123.229758, 'start': 1122.953313, 'word': 'for'},
#    {'conf': 0.595098, 'end': 1123.643313, 'start': 1123.229758, 'word': 'the'},
#    {'conf': 1.0, 'end': 1125.413313, 'start': 1124.633313, 'word': 'cash'}],
#   'text': 'check ahead for the cash'},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.405133,
#     'end': 1140.353313,
#     'start': 1139.003313,
#     'word': 'technician'}],
#   'text': 'technician'},
#  {'result': [{'conf': 0.655492,
#     'end': 1146.922668,
#     'start': 1146.383313,
#     'word': 'should'},
#    {'conf': 0.641656,
#     'end': 1147.673313,
#     'start': 1146.923313,
#     'word': 'know'}],
#   'text': 'should know'},
#  {'result': [{'conf': 0.950961,
#     'end': 1149.803313,
#     'start': 1149.593313,
#     'word': 'two'},
#    {'conf': 0.505976,
#     'end': 1150.313313,
#     'start': 1149.803313,
#     'word': 'fresh'},
#    {'conf': 0.810609,
#     'end': 1150.943313,
#     'start': 1150.313313,
#     'word': 'challenge'}],
#   'text': 'two fresh challenge'},
#  {'result': [{'conf': 0.94854,
#     'end': 1154.405032,
#     'start': 1153.733313,
#     'word': 'sharing'},
#    {'conf': 0.439898,
#     'end': 1155.143313,
#     'start': 1154.693313,
#     'word': 'caring'}],
#   'text': 'sharing caring'},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 1.0,
#     'end': 1169.153313,
#     'start': 1168.433313,
#     'word': 'ah'},
#    {'conf': 0.578504, 'end': 1170.023313, 'start': 1169.603313, 'word': 'ash'},
#    {'conf': 0.487324,
#     'end': 1170.923313,
#     'start': 1170.053313,
#     'word': 'char'}],
#   'text': 'ah ash char'},
#  {'result': [{'conf': 0.45873,
#     'end': 1174.103313,
#     'start': 1173.533313,
#     'word': 'trash'}],
#   'text': 'trash'},
#  {'result': [{'conf': 0.444957,
#     'end': 1176.413313,
#     'start': 1175.273313,
#     'word': 'her'},
#    {'conf': 0.615546, 'end': 1177.643313, 'start': 1176.593313, 'word': 'or'},
#    {'conf': 0.68165, 'end': 1178.153313, 'start': 1177.913313, 'word': 'her'},
#    {'conf': 0.689193,
#     'end': 1179.077864,
#     'start': 1178.153665,
#     'word': 'partner'}],
#   'text': 'her or her partner'},
#  {'result': [{'conf': 0.246151,
#     'end': 1182.383313,
#     'start': 1181.483313,
#     'word': 'petals'}],
#   'text': 'petals'},
#  {'result': [{'conf': 1.0,
#     'end': 1186.201809,
#     'start': 1185.863313,
#     'word': 'she'},
#    {'conf': 0.608578,
#     'end': 1187.093313,
#     'start': 1186.201809,
#     'word': 'said'}],
#   'text': 'she said'},
#  {'result': [{'conf': 0.438974,
#     'end': 1191.563313,
#     'start': 1191.083313,
#     'word': 'hey'}],
#   'text': 'hey'},
#  {'result': [{'conf': 0.618603,
#     'end': 1194.173313,
#     'start': 1193.303313,
#     'word': 'shoot'}],
#   'text': 'shoot'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.49212,
#     'end': 1217.24,
#     'start': 1216.58,
#     'word': 'how'}],
#   'text': 'how'},
#  {'result': [{'conf': 0.365525,
#     'end': 1220.15,
#     'start': 1219.73,
#     'word': 'dirt'}],
#   'text': 'dirt'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.637855,
#     'end': 1248.280413,
#     'start': 1247.99,
#     'word': 'i'}],
#   'text': 'i'},
#  {'result': [{'conf': 0.818572,
#     'end': 1253.57,
#     'start': 1253.09,
#     'word': 'can'},
#    {'conf': 0.511441, 'end': 1253.99, 'start': 1253.6, 'word': 'do'}],
#   'text': 'can do'},
#  {'text': ''},
#  {'result': [{'conf': 0.609039,
#     'end': 1260.86,
#     'start': 1259.96,
#     'word': 'time'},
#    {'conf': 0.825101, 'end': 1262.72, 'start': 1262.54, 'word': 'for'},
#    {'conf': 0.954529, 'end': 1263.011844, 'start': 1262.72, 'word': 'that'},
#    {'conf': 0.263851, 'end': 1263.32, 'start': 1263.02, 'word': 'matter'}],
#   'text': 'time for that matter'},
#  {'result': [{'conf': 0.309761,
#     'end': 1268.39,
#     'start': 1267.67,
#     'word': "she's"},
#    {'conf': 0.258054, 'end': 1269.38, 'start': 1268.652471, 'word': 'town'}],
#   'text': "she's town"},
#  {'result': [{'conf': 0.532724, 'end': 1271.6, 'start': 1270.91, 'word': 'i'},
#    {'conf': 0.458734, 'end': 1271.994446, 'start': 1271.75, 'word': 'go'},
#    {'conf': 0.421876, 'end': 1272.41, 'start': 1271.994446, 'word': 'there'}],
#   'text': 'i go there'},
#  {'result': [{'conf': 0.899666,
#     'end': 1275.71,
#     'start': 1275.5,
#     'word': 'you'},
#    {'conf': 1.0, 'end': 1276.08741, 'start': 1275.71, 'word': 'should'},
#    {'conf': 0.450089, 'end': 1276.67, 'start': 1276.108738, 'word': 'there'}],
#   'text': 'you should there'},
#  {'result': [{'conf': 0.66414,
#     'end': 1279.13,
#     'start': 1277.78,
#     'word': 'hush'}],
#   'text': 'hush'},
#  {'result': [{'conf': 0.334325,
#     'end': 1284.14,
#     'start': 1282.58,
#     'word': 'seal'}],
#   'text': 'seal'},
#  {'result': [{'conf': 0.747502,
#     'end': 1285.994207,
#     'start': 1285.52,
#     'word': 'this'},
#    {'conf': 0.603079, 'end': 1286.45, 'start': 1286.0, 'word': 'year'}],
#   'text': 'this year'},
#  {'result': [{'conf': 0.703198,
#     'end': 1288.52,
#     'start': 1288.07,
#     'word': 'is'},
#    {'conf': 0.431603, 'end': 1289.36, 'start': 1288.82, 'word': 'there'}],
#   'text': 'is there'},
#  {'result': [{'conf': 0.899705,
#     'end': 1291.1,
#     'start': 1290.53,
#     'word': 'young'}],
#   'text': 'young'},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.383925,
#     'end': 1304.935706,
#     'start': 1304.773445,
#     'word': 'are'},
#    {'conf': 0.584882, 'end': 1305.38, 'start': 1305.074639, 'word': 'you'}],
#   'text': 'are you'},
#  {'text': ''},
#  {'text': ''},
#  {'text': ''},
#  {'result': [{'conf': 0.420871,
#     'end': 1325.27,
#     'start': 1324.82,
#     'word': 'much'}],
#   'text': 'much'},
#  {'text': ''},
#  {'result': [{'conf': 1.0, 'end': 1332.68, 'start': 1332.29, 'word': 'yeah'}],
#   'text': 'yeah'},
#  {'text': ''},
#  {'result': [{'conf': 0.300207,
#     'end': 1341.08,
#     'start': 1340.36,
#     'word': 'an'}],
#   'text': 'an'},
#  {'text': ''},
#  {'result': [{'conf': 0.75719,
#     'end': 1353.649736,
#     'start': 1353.44,
#     'word': 'you'},
#    {'conf': 0.599815,
#     'end': 1353.979561,
#     'start': 1353.649736,
#     'word': 'should'},
#    {'conf': 0.983244, 'end': 1354.73, 'start': 1353.979561, 'word': 'that'}],
#   'text': 'you should that'},
#  {'result': [{'conf': 0.289266,
#     'end': 1357.91,
#     'start': 1356.74,
#     'word': 'spooky'}],
#   'text': 'spooky'},
#  {'result': [{'conf': 0.735602,
#     'end': 1365.569668,
#     'start': 1365.35,
#     'word': 'i'},
#    {'conf': 0.612114,
#     'end': 1365.843726,
#     'start': 1365.569668,
#     'word': 'have'}],
#   'text': 'i have'}]

# %% [markdown]
# `results` - list of json dictionaries, each of them has the following structure:
#
# ```
# {'result': [
#   # first word in a sentence
#   {'conf': 0.84, # confidence
#    'end': 4.5, # end time
#    'start': 4.05, # start time
#    'word': 'test'},
#   # then, same parameters for
#   # the second word in a sentence
#   {'conf': 0.87,
#    'end': 5.7,
#    'start': 5.1,
#    'word': 'library'},
#   ... ], # and so on
#  # and a full text of the sentence
#  'text': 'test library ...'}
#  ```

# %%
results
# Out:
# [{'result': [{'conf': 1.0, 'end': 1.92, 'start': 1.47, 'word': 'some'},
#    {'conf': 1.0, 'end': 2.4, 'start': 1.92, 'word': 'speech'},
#    {'conf': 1.0, 'end': 3.09, 'start': 2.4, 'word': 'recognition'},
#    {'conf': 1.0, 'end': 4.02, 'start': 3.09, 'word': 'systems'},
#    {'conf': 1.0, 'end': 4.8, 'start': 4.08, 'word': 'require'},
#    {'conf': 1.0, 'end': 5.67, 'start': 4.92, 'word': 'training'},
#    {'conf': 1.0, 'end': 6.9, 'start': 6.03, 'word': 'alphago'},
#    {'conf': 0.720008, 'end': 7.95, 'start': 6.93, 'word': 'enrollment'},
#    {'conf': 0.739668, 'end': 8.7, 'start': 8.34, 'word': 'burn'},
#    {'conf': 1.0, 'end': 9.42, 'start': 8.7, 'word': 'individual'},
#    {'conf': 1.0, 'end': 10.17, 'start': 9.42, 'word': 'speaker'},
#    {'conf': 0.670045, 'end': 10.68, 'start': 10.23, 'word': 'reads'},
#    {'conf': 1.0, 'end': 11.34, 'start': 10.689899, 'word': 'text'},
#    {'conf': 0.987625, 'end': 11.7, 'start': 11.37, 'word': 'or'},
#    {'conf': 1.0, 'end': 12.48, 'start': 11.73, 'word': 'isolated'},
#    {'conf': 1.0, 'end': 13.41, 'start': 12.48, 'word': 'vocabulary'},
#    {'conf': 1.0, 'end': 13.77, 'start': 13.44, 'word': 'into'},
#    {'conf': 1.0, 'end': 13.95, 'start': 13.77, 'word': 'the'},
#    {'conf': 1.0, 'end': 14.55, 'start': 13.95, 'word': 'system'},
#    {'conf': 1.0, 'end': 15.36, 'start': 15.15, 'word': 'the'},
#    {'conf': 1.0, 'end': 15.9, 'start': 15.36, 'word': 'system'},
#    {'conf': 1.0, 'end': 16.86, 'start': 15.93, 'word': 'analyzes'},
#    {'conf': 1.0, 'end': 17.1, 'start': 16.89, 'word': 'the'},
#    {'conf': 0.852506, 'end': 17.55, 'start': 17.1, 'word': 'person'},
#    {'conf': 1.0, 'end': 18.24, 'start': 17.558849, 'word': 'specific'},
#    {'conf': 1.0, 'end': 18.87, 'start': 18.24, 'word': 'voice'},
#    {'conf': 1.0, 'end': 19.41, 'start': 19.17, 'word': 'and'},
#    {'conf': 1.0, 'end': 19.89, 'start': 19.41, 'word': 'use'},
#    {'conf': 1.0, 'end': 20.16, 'start': 19.89, 'word': 'it'}],
#   'text': 'some speech recognition systems require training alphago enrollment burn individual speaker reads text or isolated vocabulary into the system the system analyzes the person specific voice and use it'},
#  {'result': [{'conf': 1.0, 'end': 20.73, 'start': 20.52, 'word': 'to'},
#    {'conf': 0.987695, 'end': 21.12, 'start': 20.73, 'word': 'fine'},
#    {'conf': 0.987695, 'end': 21.509308, 'start': 21.12, 'word': 'tune'},
#    {'conf': 0.964927, 'end': 21.66, 'start': 21.51, 'word': 'the'},
#    {'conf': 1.0, 'end': 22.53, 'start': 21.66, 'word': 'recognition'},
#    {'conf': 1.0, 'end': 22.8, 'start': 22.56, 'word': 'of'},
#    {'conf': 0.530819, 'end': 23.01, 'start': 22.8, 'word': 'the'},
#    {'conf': 0.771107, 'end': 23.574979, 'start': 23.04, 'word': "person's"},
#    {'conf': 1.0, 'end': 24.21, 'start': 23.574979, 'word': 'speech'},
#    {'conf': 1.0, 'end': 25.05, 'start': 24.24, 'word': 'resulting'},
#    {'conf': 1.0, 'end': 25.35, 'start': 25.08, 'word': 'in'},
#    {'conf': 1.0, 'end': 26.07, 'start': 25.35, 'word': 'increased'},
#    {'conf': 1.0, 'end': 26.91, 'start': 26.1, 'word': 'accuracy'},
#    {'conf': 1.0, 'end': 28.35, 'start': 27.48, 'word': 'systems'},
#    {'conf': 1.0, 'end': 28.59, 'start': 28.35, 'word': 'that'},
#    {'conf': 1.0, 'end': 28.77, 'start': 28.62, 'word': 'do'},
#    {'conf': 1.0, 'end': 29.31, 'start': 28.77, 'word': 'not'},
#    {'conf': 1.0, 'end': 29.76, 'start': 29.31, 'word': 'use'},
#    {'conf': 1.0, 'end': 30.45, 'start': 29.79, 'word': 'training'},
#    {'conf': 0.761007, 'end': 30.717166, 'start': 30.48, 'word': 'are'},
#    {'conf': 1.0, 'end': 31.08, 'start': 30.717166, 'word': 'called'},
#    {'conf': 1.0, 'end': 31.65, 'start': 31.08, 'word': 'speaker'},
#    {'conf': 1.0, 'end': 32.58, 'start': 31.65, 'word': 'independent'},
#    {'conf': 1.0, 'end': 33.36, 'start': 32.58, 'word': 'systems'},
#    {'conf': 1.0, 'end': 34.77, 'start': 33.87, 'word': 'systems'},
#    {'conf': 1.0, 'end': 35.19, 'start': 34.83, 'word': 'that'},
#    {'conf': 1.0, 'end': 35.67, 'start': 35.19, 'word': 'use'},
#    {'conf': 1.0, 'end': 36.39, 'start': 35.7, 'word': 'training'},
#    {'conf': 0.59374, 'end': 36.66, 'start': 36.45, 'word': 'are'},
#    {'conf': 1.0, 'end': 37.14, 'start': 36.66, 'word': 'called'},
#    {'conf': 1.0, 'end': 37.74, 'start': 37.17, 'word': 'speaker'},
#    {'conf': 1.0, 'end': 38.67, 'start': 37.74, 'word': 'dependent'}],
#   'text': "to fine tune the recognition of the person's speech resulting in increased accuracy systems that do not use training are called speaker independent systems systems that use training are called speaker dependent"}]

# %%
# convert list of JSON dictionaries to list of 'Word' objects

list_of_words = []
for sentence in results:
    if len(sentence) == 1:
        # sometimes there are bugs in recognition 
        # and it returns an empty dictionary
        # {'text': ''}
        continue
    for obj in sentence['result']:
        w = custom_Word.Word(obj)  # create custom Word object
        list_of_Words.append(w)  # and add it to list

# %%
for word in list_of_words:
    print(word.to_string())
# Out:
# some                 from 1.47 sec to 1.92 sec, confidence is 100.00%
# speech               from 1.92 sec to 2.40 sec, confidence is 100.00%
# recognition          from 2.40 sec to 3.09 sec, confidence is 100.00%
# systems              from 3.09 sec to 4.02 sec, confidence is 100.00%
# require              from 4.08 sec to 4.80 sec, confidence is 100.00%
# training             from 4.92 sec to 5.67 sec, confidence is 100.00%
# alphago              from 6.03 sec to 6.90 sec, confidence is 100.00%
# enrollment           from 6.93 sec to 7.95 sec, confidence is 72.00%
# burn                 from 8.34 sec to 8.70 sec, confidence is 73.97%
# individual           from 8.70 sec to 9.42 sec, confidence is 100.00%
# speaker              from 9.42 sec to 10.17 sec, confidence is 100.00%
# reads                from 10.23 sec to 10.68 sec, confidence is 67.00%
# text                 from 10.69 sec to 11.34 sec, confidence is 100.00%
# or                   from 11.37 sec to 11.70 sec, confidence is 98.76%
# isolated             from 11.73 sec to 12.48 sec, confidence is 100.00%
# vocabulary           from 12.48 sec to 13.41 sec, confidence is 100.00%
# into                 from 13.44 sec to 13.77 sec, confidence is 100.00%
# the                  from 13.77 sec to 13.95 sec, confidence is 100.00%
# system               from 13.95 sec to 14.55 sec, confidence is 100.00%
# the                  from 15.15 sec to 15.36 sec, confidence is 100.00%
# system               from 15.36 sec to 15.90 sec, confidence is 100.00%
# analyzes             from 15.93 sec to 16.86 sec, confidence is 100.00%
# the                  from 16.89 sec to 17.10 sec, confidence is 100.00%
# person               from 17.10 sec to 17.55 sec, confidence is 85.25%
# specific             from 17.56 sec to 18.24 sec, confidence is 100.00%
# voice                from 18.24 sec to 18.87 sec, confidence is 100.00%
# and                  from 19.17 sec to 19.41 sec, confidence is 100.00%
# use                  from 19.41 sec to 19.89 sec, confidence is 100.00%
# it                   from 19.89 sec to 20.16 sec, confidence is 100.00%
# to                   from 20.52 sec to 20.73 sec, confidence is 100.00%
# fine                 from 20.73 sec to 21.12 sec, confidence is 98.77%
# tune                 from 21.12 sec to 21.51 sec, confidence is 98.77%
# the                  from 21.51 sec to 21.66 sec, confidence is 96.49%
# recognition          from 21.66 sec to 22.53 sec, confidence is 100.00%
# of                   from 22.56 sec to 22.80 sec, confidence is 100.00%
# the                  from 22.80 sec to 23.01 sec, confidence is 53.08%
# person's             from 23.04 sec to 23.57 sec, confidence is 77.11%
# speech               from 23.57 sec to 24.21 sec, confidence is 100.00%
# resulting            from 24.24 sec to 25.05 sec, confidence is 100.00%
# in                   from 25.08 sec to 25.35 sec, confidence is 100.00%
# increased            from 25.35 sec to 26.07 sec, confidence is 100.00%
# accuracy             from 26.10 sec to 26.91 sec, confidence is 100.00%
# systems              from 27.48 sec to 28.35 sec, confidence is 100.00%
# that                 from 28.35 sec to 28.59 sec, confidence is 100.00%
# do                   from 28.62 sec to 28.77 sec, confidence is 100.00%
# not                  from 28.77 sec to 29.31 sec, confidence is 100.00%
# use                  from 29.31 sec to 29.76 sec, confidence is 100.00%
# training             from 29.79 sec to 30.45 sec, confidence is 100.00%
# are                  from 30.48 sec to 30.72 sec, confidence is 76.10%
# called               from 30.72 sec to 31.08 sec, confidence is 100.00%
# speaker              from 31.08 sec to 31.65 sec, confidence is 100.00%
# independent          from 31.65 sec to 32.58 sec, confidence is 100.00%
# systems              from 32.58 sec to 33.36 sec, confidence is 100.00%
# systems              from 33.87 sec to 34.77 sec, confidence is 100.00%
# that                 from 34.83 sec to 35.19 sec, confidence is 100.00%
# use                  from 35.19 sec to 35.67 sec, confidence is 100.00%
# training             from 35.70 sec to 36.39 sec, confidence is 100.00%
# are                  from 36.45 sec to 36.66 sec, confidence is 59.37%
# called               from 36.66 sec to 37.14 sec, confidence is 100.00%
# speaker              from 37.17 sec to 37.74 sec, confidence is 100.00%
# dependent            from 37.74 sec to 38.67 sec, confidence is 100.00%

# %%
# forming a final string from the words
text = ''
for r in results:
    text += r['text'] + ' '

print("\tVosk thinks you said:\n")
print(text)
# Out:
# 	Vosk thinks you said:
#
# some speech recognition systems require training alphago enrollment burn individual speaker reads text or isolated vocabulary into the system the system analyzes the person specific voice and use it to fine tune the recognition of the person's speech resulting in increased accuracy systems that do not use training are called speaker independent systems systems that use training are called speaker dependent

# %%
print(f"Saving text to '{text_filename}'...")
with open(text_filename, "w") as text_file:
    text_file.write(text)
print(f"Text successfully saved")
# Out:
# Saving text to '../audio/speech_recognition_systems_vosk_with_timestamps.txt'...
# Text successfully saved
